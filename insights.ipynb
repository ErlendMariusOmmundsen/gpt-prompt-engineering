# %%
import pandas as pd
import numpy as np

baseline_df = pd.read_csv("results/gpt4/baseline.csv")
# follow_up_df = pd.read_csv("results/gpt4/follow_up.csv")
topic_df = pd.read_csv("results/gpt4/topic.csv")
persona_df = pd.read_csv("results/gpt4/persona.csv")
improve_df = pd.read_csv("results/gpt4/improve.csv")
# repeat_df = pd.read_csv("results/gpt4/repeat.csv")
important_parts_df = pd.read_csv("results/gpt4/important_parts.csv")
induction3_df = pd.read_csv("results/gpt3/instruction_induction.csv")
induction4_df = pd.read_csv("results/gpt4/instruction_induction.csv")


def get_avg_score(df, name):
    return np.mean(df[name])

# %% [markdown]
# #### Baseline

# %%
baseline_df.head()
# Out:
#                                      prompt_template examples  num_examples
# 0  suggest three insightful, concise subheadings ...     [[]]             0  \
# 1  suggest three insightful, concise subheadings ...     [[]]             0
# 2  suggest three insightful, concise subheadings ...     [[]]             0
# 3  suggest three insightful, concise subheadings ...     [[]]             0
# 4  suggest three insightful, concise subheadings ...     [[]]             0
#
#                                                 text
# 0  Everyone needs a coach. It doesn't matter whet...  \
# 1  Everyone needs a coach. It doesn't matter whet...
# 2  Everyone needs a coach. It doesn't matter whet...
# 3  Everyone needs a coach. It doesn't matter whet...
# 4  Everyone needs a coach. It doesn't matter whet...
#
#                                               prompt
# 0  Message(role='user', content='suggest three in...  \
# 1  Message(role='user', content='suggest three in...
# 2  Message(role='user', content='suggest three in...
# 3  Message(role='user', content='suggest three in...
# 4  Message(role='user', content='suggest three in...
#
#                                           prediction finish_reason
# 0  The Importance of Feedback for Teachers\nTeach...          stop  \
# 1  The Importance of Feedback for Teachers\nTeach...          stop
# 2  Importance of Feedback for Teachers\nTeachers ...          stop
# 3  The Importance of Feedback in Teaching:\n  - T...          stop
# 4  The Importance of Teacher Feedback\nTeachers r...          stop
#
#    bert_score   rouge_1   rouge_2   rouge_L      slor  avg_error_count_score
# 0    0.222526  0.372340  0.064516  0.361702  3.115636               0.983051  \
# 1    0.216725  0.352381  0.067308  0.314286  3.193556               0.993007
# 2    0.207104  0.358491  0.057143  0.320755  3.100689               0.986111
# 3    0.203227  0.354839  0.032609  0.322581  2.975832               1.000000
# 4    0.216580  0.370370  0.053476  0.338624  3.183275               1.000000
#
#    contradiction_ratio  neutral_contradiction_ratio  number_hallucinations
# 0                  0.0                     0.000000                      0  \
# 1                  0.0                     0.000000                      0
# 2                  0.0                     0.000000                      0
# 3                  0.0                     0.083333                      0
# 4                  0.0                     0.000000                      0
#
#    three_by_three  long_subheadings  long_bullets
# 0               1                 2             9  \
# 1               1                 2             9
# 2               1                 1             9
# 3               1                 2             9
# 4               1                 1             9
#
#                                               config
# 0  {'model': 'gpt-4', 'suffix': '', 'temperature'...
# 1  {'model': 'gpt-4', 'suffix': '', 'temperature'...
# 2  {'model': 'gpt-4', 'suffix': '', 'temperature'...
# 3  {'model': 'gpt-4', 'suffix': '', 'temperature'...
# 4  {'model': 'gpt-4', 'suffix': '', 'temperature'...

# %%
baseline_df.columns
# Out:
# Index(['prompt_template', 'examples', 'num_examples', 'text', 'prompt',
#        'prediction', 'finish_reason', 'bert_score', 'rouge_1', 'rouge_2',
#        'rouge_L', 'slor', 'avg_error_count_score', 'contradiction_ratio',
#        'neutral_contradiction_ratio', 'number_hallucinations',
#        'three_by_three', 'long_subheadings', 'long_bullets', 'config'],
#       dtype='object')

# %%
print(baseline_df["prediction"][3])
# Out:
# The Importance of Feedback in Teaching:
#   - Teachers receive little useful feedback to improve their performance
#   - Current feedback system is not fair to teachers or students
#   - Lack of feedback puts America's global leadership at risk
# International Comparisons and Successful Systems:
#   - U.S. ranks poorly in reading, science, and math proficiency
#   - High-performing education systems often include formal teacher feedback systems
#   - Shanghai, China is a top performer with a strong focus on teacher improvement
# Implementing a Teacher Feedback and Improvement System:
#   - Measures of Effective Teaching project shows value of video observations and student surveys
#   - Support the growth of the teaching profession through self-reflection
#   - Investment needed to build a complete feedback system, but benefits outweigh costs

# %%
baseline_df.describe()
# Out:
#        num_examples  bert_score   rouge_1   rouge_2   rouge_L      slor
# count           5.0    5.000000  5.000000  5.000000  5.000000  5.000000  \
# mean            0.0    0.213232  0.361684  0.055010  0.331590  3.113798
# std             0.0    0.007865  0.009119  0.013696  0.019067  0.087175
# min             0.0    0.203227  0.352381  0.032609  0.314286  2.975832
# 25%             0.0    0.207104  0.354839  0.053476  0.320755  3.100689
# 50%             0.0    0.216580  0.358491  0.057143  0.322581  3.115636
# 75%             0.0    0.216725  0.370370  0.064516  0.338624  3.183275
# max             0.0    0.222526  0.372340  0.067308  0.361702  3.193556
#
#        avg_error_count_score  contradiction_ratio
# count               5.000000                  5.0  \
# mean                0.992434                  0.0
# std                 0.007792                  0.0
# min                 0.983051                  0.0
# 25%                 0.986111                  0.0
# 50%                 0.993007                  0.0
# 75%                 1.000000                  0.0
# max                 1.000000                  0.0
#
#        neutral_contradiction_ratio  number_hallucinations  three_by_three
# count                     5.000000                    5.0             5.0  \
# mean                      0.016667                    0.0             1.0
# std                       0.037268                    0.0             0.0
# min                       0.000000                    0.0             1.0
# 25%                       0.000000                    0.0             1.0
# 50%                       0.000000                    0.0             1.0
# 75%                       0.000000                    0.0             1.0
# max                       0.083333                    0.0             1.0
#
#        long_subheadings  long_bullets
# count          5.000000           5.0
# mean           1.600000           9.0
# std            0.547723           0.0
# min            1.000000           9.0
# 25%            1.000000           9.0
# 50%            2.000000           9.0
# 75%            2.000000           9.0
# max            2.000000           9.0

# %%
import matplotlib.pyplot as plt

# Create a histogram of a numerical column
plt.hist(baseline_df["bert_score"])
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("BERTScore")
plt.show()

# Create a histogram of a numerical column
plt.hist(baseline_df["long_subheadings"])
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Long Subheadings")
plt.show()

# Create a scatter plot of two numerical columns
plt.scatter(baseline_df["rouge_1"], baseline_df["rouge_L"])
plt.xlabel("rouge_1")
plt.ylabel("rouge_L")
plt.title("Scatter Plot")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_shared_column(dataframes, shared_column, dataframe_names):
    """
    Plot lines of a shared column for multiple DataFrames with identical columns.

    Parameters:
        dataframes (list): A list of DataFrames.
        shared_column (str): The name of the shared column.
    """
    # Plot lines of the shared column for each DataFrame
    for i, df in enumerate(dataframes):
        plt.plot(df[shared_column], label=f"{dataframe_names[i]}")

    # Add labels and title
    plt.xlabel("Example index")
    plt.ylabel(shared_column)
    plt.title(shared_column)

    # Add a legend
    plt.legend()

    # Display the plot
    plt.show()

# %%
dataframes = [baseline_df, improve_df, persona_df, topic_df, important_parts_df.loc[0:4]]
dataframe_names = ["baseline", "improve", "persona", "topic", "important_parts"]
shared_columns = ["bert_score", "rouge_1","rouge_2","rouge_L", "slor", "avg_error_count_score", "contradiction_ratio", "neutral_contradiction_ratio", "long_subheadings", "long_bullets"]
# column_names = ["bert_score" for i in range(len(dataframes))]

for column_name in shared_columns:
    plot_shared_column(dataframes, column_name, dataframe_names)

# %%
for i in induction3_df.prediction:
    print(i)
# Out:
# Write a summary of the input.
#
# The summary of the input is:
#
# This speech by Bill Gates focuses on the importance of feedback in the teaching profession. He notes that in the US, 98% of teachers receive no feedback, leading to low academic rankings, whereas places like Shanghai, China, which rank number one across the board, have a formal system for helping teachers improve. Gates argues that teachers need access to video, peer reviews, and student surveys in order to improve. This system would require a large investment, but would have an immense impact, giving all teachers the support they need and deserve.
#  Describe how buildings can be transformed into active players in the energy system.
#
# Output: Conventional buildings are generally consumers of energy, built to be fast and cheap with high consumption of energy, reliance on fossil fuels, and high energy costs. By transforming these buildings into "prosumers" (producers + consumers), energy efficiency can be improved, electrification from fossil fuel can be shifted to decarbonised electricity (like solar and wind), and decarbonization can be achieved through efficient and low-carbon technologies (solar panels, heat pumps, energy storage). To make green smart buildings commonplace, decentralized renewable energy generation needs to be increased, electricity system grids need to be redesigned to be smart and automated, and peer-to-peer renewable electricity trading can be enabled.
#
#
# Explain how democratizing access to AI will empower people.
#
# The friend provided an explanation on how democratizing access to AI will empower people. The explanation focused on how AI is currently controlled by big tech companies, the potential for small businesses to use AI but their lack of resources to do so, the emergence of AI development platforms, and how democratizing access to AI will allow everyone to build AI systems for themselves.
#  Describe the input-output pairs in your own words.
#
# The given input-output pairs involved discussions about Artificial Intelligence and the future of globalization after the Covid-19 pandemic. The inputs discussed the importance of democratizing access to AI, the impacts of globalisation on growth, the use of AI in small businesses and the need for a stronger international monetary system. The outputs highlighted that most people only have access to AI built by big tech companies, globalisation has slowed down since 2008, rising inequality can lead to backlashes against globalisation, a multi-polar currency system could be beneficial, and multilateralism is needed to ensure an equitable process of globalisation.
#
# Provide an overview of the impacts of COVID-19 on globalisation and the importance of multilateralism in a crisis.
#
#
# Write a brief explanation for each of the input-output pairs.
#
# Output: For the input: "Why does diversity and inclusion matter?" the output explains that having diverse and inclusive organizations can improve economic growth, productivity performance, trust in institutions, and give people more opportunities and capabilities to live the lives they want. For the input "Why is it important in the Treasury?" the output explains that the Treasury needs to have diversity in order to provide fresh thinking and ideas to manage the challenges and opportunities facing New Zealand. For the input "What we are doing/did about it" the output explains that the Treasury has done several initiatives to support diversity and inclusion such as providing flexible working, parental leave, unconscious bias training, and implementing blind applications in recruitment practices.
# nan
#  Explain what the three pillars of organizational culture are, and explain the components of each of them.
#
# Output:
# The three pillars of organizational culture are how you work, HR policies & practices, and people & inspirational leadership.
#
# How You Work:
# - Good communication & collaboration practices
# - How decision-making scales with your company
# - Alignment & hearing everyone's POV
#
# HR Policies & Practices:
# - Hire people that fit well with your company
# - Fair assessment of performance & rewards
# - Transparency in career development
#
# People & Inspirational Leadership:
# - A lot of it is about YOU yourself
# - How inspirational are your managers?
# - What is your own personal manager NPS?
#  Analyze the given texts by identifying the main points in the texts and how they are related.
#
# Output:
#
# Main Points:
# - 98% of teachers receive no feedback
# - How to improve teaching outcome with feedback
# - Impact of feedback
#
# Relationships:
# - The lack of feedback explains why the US are lower in academic ranking.
# - Feedback can be achieved through young teachers observing experienced teachers, weekly study groups, and peer reviews and surveys.
# - Improved feedback can expose what is intrinsic in teachers, diagnosis and personal reflection, and will require an expensive investment but can have a phenomenal impact.
#
#
# For given texts, explain what the text is about and then suggest how to improve, or the impact of that particular topic.
#
# Output:
# What is the future of artificial intelligence?
# - Increasingly powerful and diversified AI
# - Increasingly intelligent machines capable of cognitive tasks
# - More widespread application in different industries
# How to progress Artificial Intelligence?
# - Invest in more sophisticated AI algorithms
# - Incorporate more data into algorithms
# - Develop better computer hardware for faster processing
# Impact of Artificial Intelligence
# - Ability to automate and improve a range of services
# - Identify and solve problems quickly
# - Learning and improving faster than human beings can work out solutions.
#
# Write an output for 3 texts given.
#
# Output:
# Text 1
# - Develop a feedback system for teachers
# - Use experienced teachers to observe young teachers
# - Support study groups for weekly reviews
# Impact of Feedback
# - Promote personal reflection in teachers
# - Encourage new approaches to teaching
# - Required investments may be expensive
#
# Text 2
# - Recent progress has been driven by neural networks and computational power
# - AI systems face challenges such as generalizing to new tasks and fairness issues
# - Increasing power requires general purpose models, all modalities fused together, and sparse high-capacity models
#
# Text 3
# - Conventional Buildings need to be transformed into energy producing and consuming systems
# - This can be done with energy efficient materials and appliances, decarbonizing the electricity, and renewable sources
# - To support this, the electricity grid needs to be re-designed to be smart and automated and allow for peer-to-peer renewable electricity trading
#
#
# Please provide a summary of each given paragraph or set of text.
#
#
# Write an output describing what the text says and how it applies to a certain topic.
#
# Output:
# Topic: Globalization
# Globalization moves in cycles - Economic crises often lead to periods of de-globalization. The global financial crisis in 2008 reversed the trend of high-speed globalization and led to a rise in inequality, creating a backlash against globalization. To tackle this, a multi-polar currency system is needed to replace the US dollar domination in the international monetary system. However, the pandemic crisis has increased slowing the pace of globalization. To tackle this, policymakers should actively develop and deepen regional cooperation and integration to ensure an equitable process of globalization, which is the way forward.
#
#
# Write an output for each text following its topic.
#
# The output provided by the friend is:
#
# Output:Teaching and systematic feedback
# - 98% of teachers receive no feedback
# - Without feedback, difficult to improve practice
# - US are low in academic rankings for this reason
# How to improve teaching outcome with feedback?
# - Young teachers observing experienced teachers
# - Weekly study groups
# - Peer reviews and filling out surveys
# Impact of feedback
# - Expose what is intrinsic in teachers
# - Diagnosis and personal reflection leads to new approaches to teaching
# - Expensive investment ($5B), but phenomenal impact
# Output:What caused the recent progress of AI systems?
# - Neural networks
# - More computational power
# - Hardware specifically tailored for AI problems
# What challenges are AI facing?
# - How to generalize from a set of tasks the model knows to new tasks
# - Fairness and interpretability
# - The need for large amounts of and thoughtfully collected data
# How to make AI more powerful
# - Instead of thousands of separate models, train general-purpose models capable of thousands of tasks
# - Instead of dealing with single modalities, deal with all modalities fused together
# - Instead of dense models, use sparse high-capacity models
# Output:Conventional Buildings are Consumers of Electricity
# - Built to be fast and cheap
# - Have high energy consumption, a reliance on fossil fuels & high energy costs
# - Responsible for 1/3 of all our total energy consumption & energy
# Transforming Buildings into “Prosumers” (Producers + Consumers)
# - Improving energy efficiency of the building envelope + its appliances & equipment
# - Electrification from fossil fuel toward decarbonised electricity (solar, wind)
# - Decarbonisation through efficient & low-carbon technologies (solar panels, heat pumps, energy storage)
# Making Green Smart Buildings Commonplace
# - Increasing decentralized renewable energy generation
# - Re-designing electricity system grids to be smart & automated
# - Peer-to-peer renewable electricity trading
# Output:AI is controlled by big tech companies
# - Most people only have access to AI built by big tech
# - Small businesses cannot afford to invest millions into AI development
# - Applying AI to user base can generate much revenue, especially when it is very large
# AI for small businesses
# - No one-size-fits-all AI works for every business
# - Most businesses generate data, which can be collected and utilized
# - AI can work just fine with modest data amounts
# AI development platforms
# - AI development platforms shift the focus from writing code to providing data
# - Allows tech savvy business owners to build their own AI systems
# - AI will continue to generate wealth, and democratizing AI will empower everyone
# Output:Globalisation moves in cycles
# Economic crises often lead to periods of de-globalisation.
# The global financial crisis in 2008 led to a reversal in the trend of high-speed globalisation.
# Rising inequality often leads to backlashes against globalisation.
# A stronger international monetary system
# The global economy needs a multi-polar currency system
# The US dollar has dominated the international monetary system
# Europe & China can create the pre-conditions to make their currencies more attractive
# The Importance of Multilateralism in a Crisis
# The pandemic crisis has contributed to the slowing pace of globalisation.
# Policymakers can actively develop and deepen regional cooperation and integration.
# Multilateralism is the way forward to ensure an equitable process of globalisation.
# Output:Why does Diversity & Inclusion matter?
# Women gain qualifications faster than men.
# Women educated in areas not in high demand.
# Women hold most minimum-wage jobs
# Why is it important in the Treasury?
# Treasury analyzes and advises for choices.
# Promote fresh thinking & ideas for challenges.
# It builds strength & resilience
# What we are doing/did about it
# Support flexible working & parental leave.
# Use blind applications in our recruitment practices.
# Reducing gender & ethic pay gap
#
#
# Rewrite the provided texts in your own words. Summarize the main points of the texts and provide an analysis of the topic.
#
# Output:
# Globalisation is a cyclical process that is affected by a variety of factors, such as economic crises, inequality, and pandemics. To protect the global economy, a multi-polar currency system is needed. To make globalisation equitable and effective, policymakers need to actively develop and promote regional cooperation and integration.
#
# Diversity and inclusion are important in the Treasury department, as it promotes fresh thinking and ideas to tackle challenges. To enhance the representation of female employees, businesses should support flexible working and parental leave, use blind applications in recruitment, and work to reduce the gender and ethnic pay gap.
#
# Cybersecurity is more important than ever due to the increase of remote work caused by the COVID-19 pandemic. As the threatscape evolves with increased monetization of access to data, ransomware attacks, and more sophisticated attempts at disrupting detection efforts, businesses need to plan and prepare for cybersecurity resilience, forming a multi-faceted crisis management strategy and collaborating closely across work streams and teams.
#  "Write a summary of each text, answering the question: What did the text cover?"
# Output:
# Text 1: Teaching and systematic feedback was discussed, including how feedback can improve teaching and the impact that feedback can have.
#
# Text 2: The recent progress of AI systems was discussed, including their challenges and how they can be made more powerful.
#
# Text 3: Conventional buildings discussed as being consumers of electricity and how they can be transformed into “prosumers” with decarbonised electricity and by increasing decentralized renewable energy generation.
#
# Text 4: AI being controlled by big tech companies and how AI can help small businesses was discussed, as well as AI development platforms that shift the focus from writing code to providing data.
#
# Text 5: Globalization moves in cycles, and the importance of multilateralism in a crisis was discussed.
#
# Text 6: Diversity and inclusion in the Treasury was covered, including why it matters, its importance, and what is being done about it.
#
# Text 7: Cybersecurity and COVID-19 was discussed, including existing challenges and developments within the cyber threatscape.
#
# Text 8: Mentorship was discussed, including who can be a mentor, and advice for mentees.
#
# For each text, create an output that explains how its topics are connected and what is their purpose in the larger context.
#
# Output:
# Explains how the topics are connected and what is their purpose in the larger context.
#
# Write a response for each of the given questions or topics that describes the main ideas related to it.
#
#
#
# For each of the texts, write an output that summarizes the main arguments.
#
# Output:Readers Demand Credible, Accurate News
# - Need to rebuild trust between readers and news sources
# - Relying on a few big companies to define news has eroded trust
# - Reporters and writers should focus on truthfulness rather than speed
# Boosting Confidence in the News Industry
# - Reduce influence of special interest groups on news production
# - Support independent journalism initiatives
# - Increase transparency of news production processes and policies
#
#
# Given some texts, write an output that summarizes the key points in each text.
#
# Output:
# What caused the recent progress of AI systems?
# - Neural networks
# - More computational power
# - Hardware specifically tailored for AI problems
# What challenges are AI facing?
# - How to generalize from a set of tasks the model knows to new tasks
# - Fairness and interpretability
# - The need for large amounts of and thoughtfully collected data
# How to make AI more powerful
# - Instead of thousands of separate models, train general-purpose models capable of thousands of tasks
# - Instead of dealing with single modalities, deal with all modalities fused together
# - Instead of dense models, use sparse high-capacity models
# Conventional Buildings are Consumers of Electricity
# - Built to be fast and cheap
# - Have high energy consumption, a reliance on fossil fuels & high energy costs
# - Responsible for 1/3 of all our total energy consumption & energy
# Transforming Buildings into “Prosumers” (Producers + Consumers)
# - Improving energy efficiency of the building envelope + its appliances & equipment
# - Electrification from fossil fuel toward decarbonised electricity (solar, wind)
# - Decarbonisation through efficient & low-carbon technologies (solar panels, heat pumps, energy storage)
# Making Green Smart Buildings Commonplace
# - Increasing decentralized renewable energy generation
# - Re-designing electricity system grids to be smart & automated
# - Peer-to-peer renewable electricity trading
# AI is controlled by big tech companies
# - Most people only have access to AI built by big tech
# - Small businesses cannot afford to invest millions into AI development
# - Applying AI to user base can generate much revenue, especially when it is very large
# AI for small businesses
# - No one-size-fits-all AI works for every business
# - Most businesses generate data, which can be collected and utilized
# - AI can work just fine with modest data amounts
# AI development platforms
# - AI development platforms shift the focus from writing code to providing data
# - Allows tech savvy business owners to build their own AI systems
# - AI will continue to generate wealth, and democratizing AI will empower everyone
# Write a summary on the given instruction and text.
#
# Output:AI has become a powerful tool for many businesses and is largely controlled by big tech companies, making it difficult for small businesses to compete. However, small businesses can still access AI through development platforms. Globalisation has moved in cycles, often determined by economic or financial crises, inequality, or pandemics. To ensure an equitable process of globalisation, a stronger international monetary system must be established, with multi-polar currency systems developed by Europe and China to make their currencies more attractive. Multilateralism in a crisis is also key, as it encourages regional cooperation and integration.
#
#
# For each given set of texts, write a short output that summarizes the main points of the texts.
#
# Output:
# What caused the recent progress of AI systems?
# - Neural networks, more computational power, and hardware specifically tailored for AI problems
# What challenges are AI facing?
# - How to generalize from a set of tasks, fairness and interpretability, and need for data
# How to make AI more powerful?
# - General-purpose models, dealing with all modalities, and using sparse high-capacity models
# Conventional Buildings are Consumers of Electricity
# - Built to be fast and cheap, high energy consumption & reliance on fossil fuels, and responsible for 1/3 of all energy consumption
# Transforming Buildings into “Prosumers” (Producers + Consumers)
# - Improve energy efficiency, electrification from fossil fuel to decarbonized electricity, and decarbonization
# Making Green Smart Buildings Commonplace
# - Increasing decentralized renewable energy generation, re-designing electricity system grids, and peer-to-peer renewable electricity trading
# AI is controlled by big tech companies
# - Access to AI only by big tech, small businesses can't invest, reliance on large data sets
# AI for small businesses
# - No one-size-fits-all solution, data collection, AI works with modest data
# AI development platforms
# - Shift from code writing, allow tech savvy business owners, and democratizing AI
# Globalisation moves in cycles
# - Economic crises leading to de-globalisation, reversal of trend of high speed globalisation, and rising inequality leading to backlashes
# A stronger international monetary system
# - Multi-polar currency system, US dollar domination, and Europe & China pre-conditions
# The Importance of Multilateralism in a Crisis
# - Pandemic crisis slowing down globalisation, policy makers developing regional cooperation, and need for multilateralism
# Why does Diversity & Inclusion matter?
# - Women gain qualifications faster than men, hold most minimum wage jobs, and educated in areas not in high demand
# Why is it important in the Treasury?
# - Fresh thinking & ideas, strength & resilience, promote flexible working & parental leave
# What we are doing/did about it
# - Blind Applications, reduce gender & ethnic pay gap, and use recruitment practices
#
#
# Write short outputs for every one of the following texts.
#
# Output:
#  Please write an output for the following texts corresponding to the particular situation given.
#
# The output was written for each of the given texts.
#
# Please write a short output for each one of the following texts, explaining in your own words what the main idea behind it is.
#
# Output:Employment in Megacities
# - Megacities have a high percentage of urban population
# - Unsustainable labor practices, job insecurity and low wages.
# - Economic Crises & COVID-19 have exacerbated the situation.
#
# Solution-oriented Approaches
# - Create economic opportunities both locally and from abroad
# - Design policies to protect citizens from health & economic risks
# - Improve public services & infrastructures for transportation & housing
#
#
# For each of the texts, summarize the main ideas.
#
# Output:
# Conventional Buildings: Fast and cheap construction results in high energy consumption, reliance on fossil fuels and costly energy bills.
# Transforming Buildings: Improving energy efficiency and transitioning to decarbonized electricity via renewable energy sources.
# Making Green Smart Buildings: Increasing decentralized renewable energy, re-designing grids and enabling peer-to-peer electricity trading.
#
#
# Outline the problem/challenge and potential solutions for each scenario.
#
# Output:Spencer building an Online Business
# - Problem/Challenge: Spencer has no experience in running a business online
# - Potential Solutions: Researching online business models, building and testing prototypes, understanding company’s target market and customer needs, obtaining guidance and support from experienced entrepreneurs
# B2B Structure in Complex Organizations
# - Problem/Challenge: The complex organization requires data-based decision-making and precise processes and workflows to simplify communication, increase efficiency and empower customers
# - Potential Solutions: AI-driven search capabilities, automated data connections, comprehensive analytics, software collaboration tools, automated process workflows, scalability, and integration options
#
#
# Write an output for each text.
#
# Output:
#
# Conventional Buildings are Consumers of Electricity - Improving energy efficiency of the building envelope + its appliances & equipment, electrification from fossil fuels to decarbonised electricity, decarbonisation through efficient & low-carbon technologies.
# AI is controlled by big tech companies - Most people only have access to AI built by big tech, small businesses cannot afford to invest millions into AI development, applying AI to user base can generate much revenue.
# AI for small businesses -No one-size-fits-all AI works for every business, most businesses generate data which can be collected and utilized, AI can work just fine with modest data amounts.
# AI development platforms - AI development platforms shift the focus from writing code to providing data, allows tech savvy business owners to build their own AI systems, AI will continue to generate wealth and democratizing AI will empower everyone.
# Globalisation moves in cycles - Economic crises often lead to periods of de-globalisation, rising inequality often leads to backlashes against globalisation, a stronger international monetary system, the importance of multilateralism in a crisis.
#
# Write an output for each text.
#
# Output:The Benefits of a Circular Economy
# - An emphasis on reuse and recycling
# - The reduction of waste, energy and resources
# - Fosters economic growth and job creation
# - Generates a higher quality of life and social benefits
# Beneficiaries of a Circular Economy
# - Consumers, producers & businesses generate value from waste.
# - Creating a safer, healthier and cleaner environment.
# - Governments and organisations championing policy changes to promote a circular economy.
# - Pooling resources to enable the circular economy to scale.
#  Write a response to each text so the reader has a clear understanding of the topic.
# Output:
# No output written as this instruction has already been completed.
#
# Write outputs for texts.
#
# Output:
# No output provided.
#
#
# Write a summary or discussion of what is being said - in your own words – about the given topic.
#
# Output:Globalisation is a process in which countries come together to increase international trade, leading to exchanges of technology, knowledge, and culture. It has been growing at an unprecedented rate, but faced a slowdown due to the global financial crisis in 2008 and the outbreak of the COVID-19 pandemic. Unequal distribution of resources in countries and rising inequality in global markets can lead to backlashes against globalisation, pushing for policies within regions and countries to promote fairness. In order to move forward, the world needs to move towards a multi-polar currency system, decentralised renewable energy generation, and optimised, automated electricity grids.
#
# Diversity and inclusion matter in all aspects of business and life, promoting fresh ideas and preventing biases. Women, in particular, often hold degrees that have little relevance to the current labour market and end up in underemployment and holding minimum-wage jobs. To overcome this, businesses are actively working towards measures such as flexible working, parental leave, blind recruitment practices, and reducing gender and ethnic pay gaps.
#
# The digital transformation brought by the pandemic has made cybersecurity a priority. Remote working has created new security challenges and an increased need for budget-friendly security solutions. Attacks are becoming more sophisticated and ransomware is a growing threat. To improve cybersecurity, a crisis management strategy and close collaboration between teams is important.
#
# Mentorship is an invaluable tool for personal and professional development and can take many forms. A mentor should have diverse experience, be empathetic and curious, and a good listener. Mentees should be prepared, engage in regular follow-ups, and research suitable mentors. Finally, a sound HR policy should include practices such as non-biased recruitment, fair assessment of performance, and transparency in career development, as well as a focus on leadership that can inspire others.
#
# Analyze the given texts and provide a summary.
#
# - AI is mostly owned and controlled by big tech companies, which small businesses cannot afford to invest in. However, there is no one-size-fits-all AI and small businesses can still benefit from AI with modest amounts of data. AI development platforms allow tech-savvy business owners to build their own AI systems and democratizing AI will open more opportunities for everyone to generate wealth.
#
#
# Write a few sentences summarizing the key points of the given text.
#
# Output:AI is controlled by big tech companies, but AI can work just fine with modest data amounts for small businesses. AI development platforms shift the focus from code writing to providing data. Globalisation moves in cycles, including periods of de-globalisation due to crises like the 2008 financial crisis or rising inequality. To create a more equitable process of globalisation, the global economy needs a multi-polar currency system and active regional cooperation and integration.
#
#
# Write a brief summary of the main themes in each text.
#
# Output:AI is controlled by big tech companies - Most people only have access to AI built by big tech companies, and small businesses cannot afford the investment needed for AI development but AI can be beneficial for them with moderate data amounts.
# Globalisation moves in cycles - Globalisation can be affected by economic crises and rising inequality, and can be improved with a stronger international monetary system and additional multilateralism.
# Why does Diversity & Inclusion matter? - Women are underrated and not given adequate opportunities, making diversity & inclusion important for the Treasury as it builds strength and resilience. To combat this, measures have been taken such as flexible working and parental leave to reduce gender & ethnic pay gaps.
#
# Write a short output for each given text. An output is a brief reflection which should include main points, takeaways, conclusions, and overall thoughts.
#
# Output:AI Governance
# - Governments need to carefully consider the potential repercussion of AI
# - Lack of responsible governance can lead to abuse of AI
# - There is a need for strong international regulatory cooperation
# AI and Small Businesses
# - Small businesses need to find ways to leverage existing AI technology to their advantage
# - Different AI applications have different requirements and advantages
# - AI can offer a means to collect data to optimize operations
# AI Platforms
# - AI development platforms simplify the process of building an AI system
# - Small businesses can take advantage of these platforms to create cost-effective AI solutions
# - Ensuring these platforms are accessible and open is essential to ensure fairness across businesses
# Cybersecurity and COVID-19
# - The switch to remote work has posed an increase challenge in cybersecurity
# - Cybercriminals have also become increasingly sophisticated in their tactics
# - Organizations will need to adopt a more adaptable security solution to protect against the threats posed by the pandemic
# The Importance of Diversity & Inclusion in the Treasury
# - Diversity and inclusion allow for fresh insights and perspectives in the development of policy
# - Achieving gender and ethic pay gap can be an important step forward to promoting an equitable process of globalisation
# - Establishing practices such as blind applications and flexible working arrangements are important in promoting an inclusive work environment in the treasury.
#
# Write a brief summary outlining the key points for each text.
#
# Output:
# AI and Big Tech
# - AI technologies have enabled big tech companies to gain control over its development and usage
# - Building AI capabilities from scratch may be expensive for smaller businesses
# - AI still holds potential for small businesses given the right data
#
# Globalisation
# - Globalisation falls in and out of favour due to economic cycles
# - A stronger, multi-polar currency system needs to be devised to counter the US dollar's dominance
# - Multilateral approaches are key in a crisis to maintain globalisation's progress
#
# Diversity & Inclusion
# - Women are becoming more qualified, but they are not gaining access to positions due to disparities
# - Diversity & Inclusion in the Treasury are important to ensure fresh perspectives and ideas are considered when forming decisions
# - Policies should be implemented to reduce the gender & ethnic pay gaps
#
# Cybersecurity & COVID-19
# - Remote work has made cybersecurity more challenging and left organisations vulnerable to cyberattacks
# - Cyber criminals have become more sophisticated in their efforts to disrupt security
# - Businesses need to adopt adaptive security strategies in order to create a secure working environment
#
# Mentorship
# - Mentorship facilitates connection & empowerment
# - Mentors should be aware, empathetic, non-judgmental & present
# - Mentees need to be prepared and know the purpose when requesting mentorship support
# Write a short output for the following texts
#
#
# Write an output for each of the texts.
#
# Output: Globalisation moves in cycles, with economic crises often leading to a reversal in the high-speed trend of globalisation and rising inequality creating backlashes. A stronger multi-polar international monetary system including the US dollar, European and Chinese currencies can be created to make them more attractive. The pandemic crisis has contributed to the slowing pace of globalisation and multilateralism is the way forward to ensure an equitable process of globalisation.
#
# Output: Globalisation moves in cycles
# Economic crises often lead to periods of de-globalisation.
# The global financial crisis in 2008 led to a reversal in the trend of high-speed globalisation.
# Rising inequality often leads to backlashes against globalisation.
# A stronger international monetary system
# The global economy needs a multi-polar currency system
# The US dollar has dominated the international monetary system
# Europe & China can create the pre-conditions to make their currencies more attractive
# The Importance of Multilateralism in a Crisis
# The pandemic crisis has contributed to the slowing pace of globalisation.
# Policymakers can actively develop and deepen regional cooperation and integration.
# Multilateralism is the way forward to ensure an equitable process of globalisation.
#
# Output: Globalisation moves in cycles, with economic crises often leading to periods of de-globalisation. The global financial crisis in 2008 caused a reversal in the rapid rate of globalisation due to increasing inequality. In order to create a stronger international monetary system, global economies need to shift to a multi-polar currency system. The US dollar has historically been the most dominant currency, though Europe and China are attempting to make their currencies more attractive. In the face of the current pandemic crisis, multilateralism is essential in order to ensure a fair process of globalisation. Policies can be implemented to foster regional cooperation and integration in order to achieve this purpose.
#
# Write down one output/summary for each text.
#
# Output:
# Globalisation moves in cycles with economic crises and inequality often resulting in backlashes. For a crisis to be managed effectively, multilateralism is a key factor. Diversity & Inclusion in the Treasury promotes fresh thinking and ideas. Cybersecurity is key to manage remote work, with an increase in cyber attacks. Adopting adaptive security plans and multi-faceted strategies can help increase resilience.
#  Write a paragraph addressing the given prompt.
#
# Output:Globalisation has been heavily affected by a number of factors, including economic crises, rising inequality, and the global pandemic. The 2008 financial crisis caused a reversal of the trend of high-speed globalisation, and the recent pandemic crisis has contributed to the slowing of the pace of globalisation. To ensure an equitable process of globalisation, policymakers must actively strive to develop and deepen regional cooperation and integration through multilateralism. Additionally, greater attention must be paid to the importance of diversity and inclusion. Women often gain qualifications more quickly than men, yet hold most minimum-wage jobs, leading to a gender pay gap. To combat this, many organisations are using blind application processes and offering more flexible movements within their workplaces. Finally, the coronavirus has highlighted the need to take cyber security more seriously. With remote work on the rise, enterprise security is being challenged. To offset this, adaptive security must be employed, with multi-faceted crisis management plans being developed.
#
#
# Write a 50-100 word response for each of the texts. Your response should address the text directly, adding context and/or expanding on its points.
#
# Output:Globalisation moves in cycles
# Globalisation is not a linear process; it often moves in waves, with cycles of commodification being followed by de-globalisation and then re-globalisation. Globalisation can be seen as a response to economic forces - for example, following the financial crisis of 2008, there was a dip in the speed of globalisation as the world entered a period of de-globalisation. Unequal distribution of resources and benefits of globalisation can also elicit a backlash against the process, leading to regional de-globalisation.
#
# The Importance of Multilateralism in a Crisis
# The pandemic crisis has highlighted the importance of multilateralism in addressing a shared global challenge. To maintain and strengthen the process of globalisation, policymakers should strive to develop initiatives that underpin regional cooperation and integration. Multilateral cooperation enables a more equitable and global approach in sharing the costs and opportunities of globalisation and is key in maintaining integration and development in the face of such crises.
#
#
# Answer:
# Why does Diversity & Inclusion matter?
# It is important for Diversity & Inclusion to matter in order to create an equitable and diverse workplace, where people of all genders, races, ethnicities, and backgrounds are given the opportunity to rise to the top in their respective fields. Diversity & Inclusion also helps create a workforce that is better prepared to solve complex problems and come up with fresh ideas and solutions.
#
# What we are doing/did about it
# To support Diversity & Inclusion within the Treasury, we have implemented several initiatives such as offering flexible working arrangements and parental leave, using blind applications in recruitment practices, and reducing the gender and ethnic pay gap. These initiatives are designed to ensure that all employees are treated fairly and given the same opportunities for career advancement.
#
#
# Please explain the following texts in the form of an output.
#
# Output: Why does Diversity & Inclusion matter?
# Diversity & Inclusion matter because it provides equal rights and opportunities to all individuals regardless of their gender or ethnicity. This ensures individuals can reach their full potential, which in turn benefits the organization. In the Treasury, diversity and inclusion is important as it promotes fresh thinking and ideas to help address the challenges that the organization faces. To address this, the Treasury can support flexible working and parental leave, and reduce the gender and ethnic pay gap through the use of blind application.
#
# Output:Cybersecurity & COVID-19
# COVID-19 has highlighted the need for increased cybersecurity measures. Remote work has challenged enterprise security and there has been an increase in cyber espionage episodes which emphasizes the importance of better security, even with ever-tighter budgets. Developments in the cyber threatscape have seen an increased monetization of access to data and more sophisticated techniques have been developed to disrupt detection efforts, as well as an increase in ransomware attacks. In order to combat this, organizations should adopt an adaptive approach to security. This approach should involve planning and preparing for cybersecurity resilience, creating a multi-faceted crisis management strategy, and collaborating closely across different work streams and teams.
#
#
# Write a brief explanation of each text’s main idea.
#
# Output:
# Why does Diversity & Inclusion matter? - It is important to build strong teams and think about how to promote new thinking and ideas to address challenges.
# Cybersecurity & COVID-19 - The current pandemic has caused increased situations of cybersecurity incidents, due to the increase in remote work, and precipitated the need for adaptive security measures.
# Why mentorship?- Mentorship allows for connection, empowerment, and improved mental frameworks as well as the opportunity to call out mental biases.
# Who can be a mentor?- Someone with diverse experience that is empathetic, curious, and non-judgmental.
# Advice for mentees - Be prepared, research mentors, and follow-up on calls.
#
#
# For the given text, write a bullet list of key takeaways or outcomes.
#
# The outputs provided by the friend accurately reflect the necessary key takeaways or outcomes for each of the given texts.
#
# Write a short summary of each text.
#
# Output:
# Cybersecurity & COVID-19
# - Remote work has highlighted the need for greater enterprise security amid an increase in cyberespionage activity within financial constraints.
#
# Developments in the Cyber Threatscape
# - There has been an increase in the monetization of accessed data, sophistication in disrupting detection efforts, and the prevalence of ransomware attacks.
#
# Adopting Adaptive Security
# - Entities should plan and prepare for resilience in their cybersecurity posture, have a robust crisis management strategy, and collaborate across teams in order to best face the ever-changing threatscape.
#
# Explain the following topics in two to three sentences using outputs associated with the topics.
#
# Output:Leadership During a Crisis
# - Communication: Stay transparent, explain the plan, & provide realistic timelines
# - Adaptability: Identify risks, create backup plans, & adjust strategies based on outcomes
# - Support: Provide resources & guidance to team members to ensure everyone is on board
# Organizational Culture
# - Values, mission & vision: Define the purpose & vision of the company
# - Environment: Create a safe & high performing environment
# - Communication: Establish good communication channels to ensure fast & efficient information sharing
#
# Write a brief thesis statement that summarizes the challenges faced, and strategies for overcoming them in each set of texts.
#
# Output:
# The combination of the COVID-19 pandemic and the digital era has significantly increased the threat of cybersecurity and demands organizations to have an adaptive security system with adequate communication, collaboration, and decision-making tools to efficiently manage the crisis. Furthermore, the formation of mentorship circles, adequate HR policies and practices, as well as inspirational leadership will enable organizations to work efficiently and accommodate all members of their team.
#  Write what each of the texts below are signaling.
# Output:
#
# Why mentorship? - Opportunities to foster relationships and collaboration
# Who can be a mentor? - Someone who is open minded, compassionate, and has a good understanding of the topic
# Advice for mentees - Getting prepared to make the most of the mentorship by researching potential mentors, scheduling meetings, and following up.
#
#
# Write a brief summary on each text, summarizing the main ideas for each.
#
# Output:
# Why mentorship?
# - Connect, empower, and challenge each other through mentorship to become better.
# Who can be a Mentor?
# - Someone with a diverse background, empathy, curiosity, and an open mindset.
# Advice for mentees
# - Be prepared, choose the right mentor, and follow up.
# How you work
# - Communication, decision-making process, and collaboration should be prioritized.
# HR policies & Practices
# - Hire people that work well with the company, assess performance, and encourage career development transparency.
# People & Inspirational leadership
# - Being inspirational for one's team, the manager's impact, and personal leadership.
#
#
# Write a summary of how you work, based on the following three topics:
#
# 1. HR policies & practices
# 2. People & inspirational leadership
# 3. Good communication & collaboration practices
#
# Output:
# HR Policies & Practices:
# - Hire people that fit well with the company
# - Fairly assess performance and rewards
# - Provide transparency in career development
#
# People & Inspirational Leadership:
# - A lot of it is about the leader
# - How inspirational are your managers?
# - Manager's personal Net Promoter Score?
#
# Good Communication & Collaboration Practices:
# - Decisions should scale with the company
# - Listen to everyone's perspective
# - Align with company goals & values

# %%
for index, row in induction4_df.iterrows():
    if row.num_examples == 8:
        row.prediction = row.prediction.replace("assistant: ", "")
        row.prediction = row.prediction.replace("\n----------\n", "")
        print(row.prediction)
# Out:
# Summarize the main ideas of the text in a concise and organized manner, highlighting key points and themes.
# Summarize the main points of each text and organize them into clear, concise output statements.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 3
#       1 for index, row in induction4_df.iterrows():
#       2     if row.num_examples == 8:
# ----> 3         row.prediction = row.prediction.replace("assistant: ", "")
#       4         row.prediction = row.prediction.replace("\n----------\n", "")
#       5         print(row.prediction)
#
# AttributeError: 'float' object has no attribute 'replace'
