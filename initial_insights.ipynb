# %%
import pandas as pd
from insight_utils import print_prediction, line_plot_column, bar_groups_chart, box_plot

# %% [markdown]
# #### Data

# %%
base_path = "results/gpt-3.5-turbo-16k/"

baseline_df = pd.read_csv(base_path + "baseline.csv")
description_df = pd.read_csv(base_path + "description.csv")
follow_up_df = pd.read_csv(base_path + "follow_up.csv")
headings_first_df = pd.read_csv(base_path + "headings_first.csv")
important_parts_df = pd.read_csv(base_path + "important_parts.csv")
improve_df = pd.read_csv(base_path + "improve.csv")
persona_df = pd.read_csv(base_path + "persona.csv")
repeat_df = pd.read_csv(base_path + "repeat.csv")
step_by_step_df = pd.read_csv(base_path + "step_by_step.csv")
template_df = pd.read_csv(base_path + "template.csv")
topic_df = pd.read_csv(base_path + "topic.csv")

dataframe_names = ["baseline", "description", "follow_up", "headings_first", "important_parts", "improve", "persona", "repeat", "step_by_step", "template", "topic"]
# dataframe_names = ["baseline"]
dataframes = [baseline_df, description_df, follow_up_df, headings_first_df, important_parts_df, improve_df, persona_df, repeat_df, step_by_step_df, template_df, topic_df]
# dataframes = [baseline_df]
column_names = ["bert_score", "rogue_1"]
calculations = ["mean", "median", "max", "min", "std"]

# %% [markdown]
# # Content Overlap

# %% [markdown]
# #### BERTScore

# %%
# bar_groups_chart(dataframes, dataframe_names, "slor", y_end=3.5)
# bar_groups_chart(dataframes, dataframe_names, "avg_error_count_score")
# bar_groups_chart(dataframes, dataframe_names, "three_by_three")
# bar_groups_chart(dataframes, dataframe_names, "long_subheadings", y_end=3.2)
# bar_groups_chart(dataframes, dataframe_names, "long_bullets", y_end=13)
# bar_groups_chart(dataframes, dataframe_names, "number_hallucinations", y_end=10)


# bar_groups_chart(dataframes=dataframes, dataframe_names=dataframe_names, metric="bert_score")

box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="bert_score")

# %% [markdown]
# #### ROUGE-1

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="rogue_1")

# %% [markdown]
# #### ROUGE-2

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="rogue_2")

# %% [markdown]
# #### ROUGE-L

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="rogue_L")

# %% [markdown]
# # Hallucination and Errors

# %% [markdown]
# #### Errors

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="errors")

# %% [markdown]
# #### Contradiction ratio

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="contradiction_ratio")

# %% [markdown]
# #### Hallucination of Numbers

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="number_hallucinations")

# %% [markdown]
# #### G-EVAL consistency

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="geval_consistency")

# %% [markdown]
# # Format

# %% [markdown]
# #### Three By Three

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="three_by_three")

# %% [markdown]
# #### Number of Long Subheadings

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="long_subheadings")

# %% [markdown]
# #### Number of Long Bullets

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="long_bullets")

# %% [markdown]
# # Quality

# %% [markdown]
# #### G-EVAL Fluency

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="geval_fluency")

# %% [markdown]
# #### G-EVAL Relevance

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="geval_relevance")

# %% [markdown]
# #### G-EVAL Coherence

# %%
box_plot(dataframes=dataframes, dataframe_names=dataframe_names, metric="geval_coherence")
