# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from insight_utils import bar_groups_chart, line_plot_column
from utils import clean_transcript, clean_summary
from constants import FORMAT_MODIFIERS, LENGTH_MODIFIERS, DENSENESS_MODIFIERS, QUALITY_MODIFIERS, STRUCTURE_MODIFIERS
import textstat
import nltk

transcript_path = "data/manual_summaries2.csv"
data = pd.read_csv(transcript_path, delimiter=";")

# %% [markdown]
# #### Format

# %%
data
# Out:
#                                            transcript
# 0   When I think about the rise of AI, I'm reminde...  \
# 1   Everyone needs a coach. It doesn't matter whet...
# 2   Hi, I'm Jeff. I lead AI Research and Health at...
# 3   Buildings are not only what they seem. They ar...
# 4   My journey to become a polar specialist, photo...
# 5   "Ashley Judd, stupid fucking slut. "You can't ...
# 6   How many of us have ever seen something, thoug...
# 7   I'm a bit of a perfectionist. Now, how many ti...
# 8   Please, stand up. If you're able. Thank you. I...
# 9   We've evolved with tools, and tools have evolv...
# 10  My grandfather was a cobbler. Back in the day,...
# 11  Joseph Keller used to jog around the Stanford ...
# 12  What an intriguing group of individuals you ar...
# 13  About a year and a half ago, Stephen Lawler, w...
# 14  You may know this feeling: you wake up to mult...
#
#                                               summary
# 0   AI is controlled by big tech companies\n- Most...  \
# 1   Teaching and systematic feedback\n- 98% of tea...
# 2   What caused the recent progress of AI systems?...
# 3   Buildings from the perspective of energy\n- Co...
# 4   Close-ups of the Arctic\n- Disappearing sea ic...
# 5   Abuse on girls and women\n- Personally, econom...
# 6   Employees Reluctance to report wrongdoing\n- 4...
# 7   Pervasive Celebration of Perfectionism\n- Indi...
# 8   Personal Journey and dreams\n- Escape and the ...
# 9   Evolution of Tools and specialization\n- Evolu...
# 10  3D Printing: linking Past and Future\n- Impact...
# 11  Lessons from Obituaries\n- Analysis of obituar...
# 12  Personality Traits and Individual Differences\...
# 13  Redefining Online Maps\n- Introduction to Bing...
# 14  Water's humility\n- Water stays low, and needs...
#
#                                                 title                speaker
# 0                   How AI could empower any business              Andrew Ng  \
# 1                         Teachers need real feedback             Bill Gates
# 2   AI isn't as smart as you think -- but it could be              Jeff Dean
# 3   What if buildings created energy instead of co...     Ksenia Petrichenko
# 4                   Animal tales from icy wonderlands           Paul Nicklen
# 5   How online abuse of women has spiraled out of ...            Ashley Judd
# 6                   How whistle-blowers shape history    Kelly Richmond Pope
# 7   Our dangerous obsession with perfectionism is ...          Thomas Curran
# 8     Pussy Riot's powerful message to Vladimir Putin    Nadya Tolokonnikova
# 9   Shape-shifting tech will change work as we kno...           Sean Follmer
# 10                         What's next in 3D printing         Avi Reichental
# 11               What I learned from 2,000 obituaries            Lux Narayan
# 12     Who are you, really? The puzzle of personality           Brian Little
# 13                             Augmented-reality maps  Blaise Agüera y Arcas
# 14  Be humble -- and other lessons from the philos...           Raymond Tang
#
#                                           description
# 0   Expensive to build and often needing highly sk...  \
# 1   Until recently, many teachers only got one wor...
# 2   What is AI, really? Jeff Dean, the head of Goo...
# 3   Buildings are bad news for the climate -- but ...
# 4   Diving under the Antarctic ice to get close to...
# 5   Enough with online hate speech, sexual harassm...
# 6   Fraud researcher and documentary filmmaker Kel...
# 7   Social psychologist Thomas Curran explores how...
# 8   Nadya Tolokonnikova, founding member of the an...
# 9   What will the world look like when we move bey...
# 10  Just like his beloved grandfather, Avi Reichen...
# 11  Lux Narayan starts his day with scrambled eggs...
# 12  What makes you, you? Psychologists like to tal...
# 13  In a demo that drew gasps at TED2010, Blaise A...
# 14  How do we find fulfillment in a world that's c...
#
#                                                 topic
# 0   technology,engineering,business,entrepreneur,s...  \
# 1            culture,global issues,education,teaching
# 2   technology,future,AI,algorithm,machine learnin...
# 3   climate change,technology,design,innovation,fu...
# 4   culture,design,entertainment,animals,creativit...
# 5   global issues,computers,gender,communication,a...
# 6   politics,corruption,social change,history,soci...
# 7   culture,social change,psychology,depression,me...
# 8   politics,corruption,social change,art,activism...
# 9   technology,design,engineering,industrial desig...
# 10               technology,3D printing,manufacturing
# 11  entrepreneur,death,communication,aging,success...
# 12  psychology,communication,self,humanity,humor,T...
# 13      technology,design,cities,virtual reality,maps
# 14  philosophy,success,motivation,personal growth,...
#
#                                              summary2
# 0   AI could be transformational if everyone can u...  \
# 1   Teachers need useful feedback \n- 98% of US te...
# 2   AI is progressing quickly\n- Two keys to AI pr...
# 3   Conventional Buildings are Consumers of Electr...
# 4   Sea ice is disappearing at faster rates than e...
# 5   Online abuse of women and girls is gender righ...
# 6   People regularly see things and don’t report t...
# 7   Perfectionism is a favorite flaw\n- Socially a...
# 8   Protesting despite the consequences\n- Protest...
# 9   Tools evolve and become more specialized over ...
# 10  3D printing is revolutionizing crafting indust...
# 11  Examining 2,000+ obituaries for trends\n- Head...
# 12  All people have a mix of common and unique tra...
# 13  Interactive options for intuitive use of maps\...
# 14  Lesson 1: Humility\n- Water flows as low as po...
#
#                                              summary3
# 0   AI Control by Big Tech Companies\n- Skilled en...  \
# 1   Current teacher Feedback systems\n- 98% of US ...
# 2   AI Progress and Current Challenges\n- AI is us...
# 3   Why buildings are a problem from the perspecti...
# 4   Life in the Polar Regions\n- Spent childhood i...
# 5   The Impact of Online Misogyny\n- Online misogy...
# 6   The Challenge of Whistle-blowers\n- Retaliatio...
# 7   Perfectionism's Pervasive Influence:\n- It is ...
# 8   Challenging the System: Prisoner to Activist\n...
# 9   Evolving Tools and Need for New Interfaces\n- ...
# 10  3D Printing Transforms Manufacturing\n- 3D pri...
# 11  Analyzing Obituary Data\n- Joseph Keller's pon...
# 12  Understanding Personality Differences\n- Perso...
# 13  Revolutionizing Online Mapping\n- Microsoft's ...
# 14  The search for answers\n- Multiple unread noti...
#
#                                              summary4
# 0   The Rise of AI\n- AI is in the hands of big te...
# 1   Teachers Lack Feedback Systematically\n- 98% o...
# 2   What AI Can Do Right Now\n- AI helps computers...
# 3   Buildings as Energy System Components\n- Build...
# 4   Ice Loss Destroys an Ecosystem\n- Polar bears ...
# 5   Women of all ages suffer abuse and attacks onl...
# 6   Whistle-blowers Make Valuable Contributions at...
# 7   Perfectionism Is Not a Symbol of Success\n- Pe...
# 8   Nadya's Arrest and Trial Experience\n- Arreste...
# 9   Tools Evolved With Humanity\n- Tools are more ...
# 10  3D Printing - Personalizing Useful Things\n- I...
# 11  Obituaries Celebrates Accomplishment\n- Allow ...
# 12  Personality Psychology Neurons to Narratives\n...
# 13  Redefining How Maps Work Online\n- Increase fl...
# 14  First Lesson - Humility\n- It is okay to ask f...

# %%
data.columns
# Out:
# Index(['transcript', 'summary', 'title', 'speaker', 'description', 'topic',
#        'summary2', 'summary3', 'summary4'],
#       dtype='object')

# %%
summaries = data[['summary', 'summary2', 'summary3', 'summary4']]
melted_df = pd.melt(summaries, value_vars=summaries.columns, value_name="summary_text")
melted_df
# Out:
#     variable                                       summary_text
# 0    summary  AI is controlled by big tech companies\n- Most...
# 1    summary  Teaching and systematic feedback\n- 98% of tea...
# 2    summary  What caused the recent progress of AI systems?...
# 3    summary  Buildings from the perspective of energy\n- Co...
# 4    summary  Close-ups of the Arctic\n- Disappearing sea ic...
# 5    summary  Abuse on girls and women\n- Personally, econom...
# 6    summary  Employees Reluctance to report wrongdoing\n- 4...
# 7    summary  Pervasive Celebration of Perfectionism\n- Indi...
# 8    summary  Personal Journey and dreams\n- Escape and the ...
# 9    summary  Evolution of Tools and specialization\n- Evolu...
# 10   summary  3D Printing: linking Past and Future\n- Impact...
# 11   summary  Lessons from Obituaries\n- Analysis of obituar...
# 12   summary  Personality Traits and Individual Differences\...
# 13   summary  Redefining Online Maps\n- Introduction to Bing...
# 14   summary  Water's humility\n- Water stays low, and needs...
# 15  summary2  AI could be transformational if everyone can u...
# 16  summary2  Teachers need useful feedback \n- 98% of US te...
# 17  summary2  AI is progressing quickly\n- Two keys to AI pr...
# 18  summary2  Conventional Buildings are Consumers of Electr...
# 19  summary2  Sea ice is disappearing at faster rates than e...
# 20  summary2  Online abuse of women and girls is gender righ...
# 21  summary2  People regularly see things and don’t report t...
# 22  summary2  Perfectionism is a favorite flaw\n- Socially a...
# 23  summary2  Protesting despite the consequences\n- Protest...
# 24  summary2  Tools evolve and become more specialized over ...
# 25  summary2  3D printing is revolutionizing crafting indust...
# 26  summary2  Examining 2,000+ obituaries for trends\n- Head...
# 27  summary2  All people have a mix of common and unique tra...
# 28  summary2  Interactive options for intuitive use of maps\...
# 29  summary2  Lesson 1: Humility\n- Water flows as low as po...
# 30  summary3  AI Control by Big Tech Companies\n- Skilled en...
# 31  summary3  Current teacher Feedback systems\n- 98% of US ...
# 32  summary3  AI Progress and Current Challenges\n- AI is us...
# 33  summary3  Why buildings are a problem from the perspecti...
# 34  summary3  Life in the Polar Regions\n- Spent childhood i...
# 35  summary3  The Impact of Online Misogyny\n- Online misogy...
# 36  summary3  The Challenge of Whistle-blowers\n- Retaliatio...
# 37  summary3  Perfectionism's Pervasive Influence:\n- It is ...
# 38  summary3  Challenging the System: Prisoner to Activist\n...
# 39  summary3  Evolving Tools and Need for New Interfaces\n- ...
# 40  summary3  3D Printing Transforms Manufacturing\n- 3D pri...
# 41  summary3  Analyzing Obituary Data\n- Joseph Keller's pon...
# 42  summary3  Understanding Personality Differences\n- Perso...
# 43  summary3  Revolutionizing Online Mapping\n- Microsoft's ...
# 44  summary3  The search for answers\n- Multiple unread noti...
# 45  summary4  The Rise of AI\n- AI is in the hands of big te...
# 46  summary4  Teachers Lack Feedback Systematically\n- 98% o...
# 47  summary4  What AI Can Do Right Now\n- AI helps computers...
# 48  summary4  Buildings as Energy System Components\n- Build...
# 49  summary4  Ice Loss Destroys an Ecosystem\n- Polar bears ...
# 50  summary4  Women of all ages suffer abuse and attacks onl...
# 51  summary4  Whistle-blowers Make Valuable Contributions at...
# 52  summary4  Perfectionism Is Not a Symbol of Success\n- Pe...
# 53  summary4  Nadya's Arrest and Trial Experience\n- Arreste...
# 54  summary4  Tools Evolved With Humanity\n- Tools are more ...
# 55  summary4  3D Printing - Personalizing Useful Things\n- I...
# 56  summary4  Obituaries Celebrates Accomplishment\n- Allow ...
# 57  summary4  Personality Psychology Neurons to Narratives\n...
# 58  summary4  Redefining How Maps Work Online\n- Increase fl...
# 59  summary4  First Lesson - Humility\n- It is okay to ask f...

# %%
all_summaries = melted_df['summary_text']
textstat.set_lang("en_US")

char_counts = []
word_counts = []
sent_counts = []
sent_lengths = []
words_in_sents = []
unique_words_count = []
all_words = []

subheadings = False
bullets = False


for summary in all_summaries:
    cleaned = clean_summary(summary)   
    sents = nltk.sent_tokenize(cleaned)
    
    if subheadings:
        sents = [sents[0], sents[4], sents[8]]
        cleaned = " ".join(sents)
    
    if bullets:
        del sents[0]
        del sents[4]
        del sents[8]
        cleaned = " ".join(sents)
        
    if bullets or subheadings:
        
        sent_lengths.append([len(sent) for sent in sents])

        words = nltk.word_tokenize(cleaned)
        num_words = [len(nltk.word_tokenize(sent)) for sent in sents]
        for num in num_words:
            word_counts.append(num)

        chars = [textstat.char_count(sent) for sent in sents]
        for char in chars:
            char_counts.append(char)

        
    else:
        sent_counts.append(len(sents))
        sent_lengths.append([len(sent) for sent in sents])
        
        words = nltk.word_tokenize(cleaned)
        word_counts.append(len(words))
        
        all_words.append(words)
        unique_words_count.append(len(list(set(words))))
        
        char_counts.append(textstat.char_count(cleaned))

        total_unique_words = list(set(np.concatenate(all_words)))


if bullets or subheadings:
    df = pd.DataFrame(columns=["char_count", "word_count"])
    df["char_count"] = char_counts
    df["word_count"] = word_counts

    print(df.describe().to_latex())

else:
    df = pd.DataFrame(columns=["char_count", "word_count", "words_in_sents", "unique_words"])
    df["word_count"] = word_counts
    df["sent_count"] = sent_counts
    df["unique_words"] = unique_words_count
    df["char_count"] = char_counts

    print(df.describe().to_latex())


# get latex tabular code for mean, median, max, min, std of char, word, sent counts
# df["summary"] = all_summaries






# print(df.to_latex(columns=["title", "char_count", "word_count", "unique_words", "sent_count"], ))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#  & char_count & word_count & unique_words & sent_count \\
# \midrule
# count & 60.000000 & 60.000000 & 60.000000 & 60.000000 \\
# mean & 529.000000 & 105.433333 & 70.950000 & 12.000000 \\
# std & 68.016449 & 13.825016 & 8.999859 & 0.000000 \\
# min & 413.000000 & 75.000000 & 48.000000 & 12.000000 \\
# 25% & 472.250000 & 94.000000 & 64.000000 & 12.000000 \\
# 50% & 522.500000 & 106.000000 & 72.000000 & 12.000000 \\
# 75% & 578.250000 & 116.500000 & 77.000000 & 12.000000 \\
# max & 733.000000 & 133.000000 & 88.000000 & 12.000000 \\
# \bottomrule
# \end{tabular}
